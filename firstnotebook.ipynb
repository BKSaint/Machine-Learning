# %% [markdown]
# Bar Graph

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy

bar_labels = ['A','B','C','D']
bar_heights = [3, 7, 4, 2]

plt.bar(bar_labels, bar_heights)
plt.show()

# %% [markdown]
# Line Graph

# %%
x = [1, 6, 3, 7, 9, 3, 0 ,3, 4, 6]
y = [1, 5, 6, 7, 8, 9, 3, 7, 6, 5]
plt.scatter(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
